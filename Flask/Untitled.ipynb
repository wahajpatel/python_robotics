# %%
import pandas as pd
from flask import *
import xlrd

# %%
server = 'p-lda-sqldb.cjppsdhni2np.us-west-2.rds.amazonaws.com,7899'
	db = 'legal_db'
	username = 'legal_srv'
	password = 'Opportunity1'
	conn = pyodbc.connect('DRIVER={SQL Server};SERVER=' + server + ';DATABASE=' + db + ';UID=' + username + ';PWD=' + password)

	sql = """
	SELECT top 10 *
	FROM dbo.lamp_pos

	"""

	df = pandas.io.sql.read_sql(sql, conn)
# Out:
#                                      Status Created_Date  Type  \
# Z00000000000000239  Available to Order (PP)   2014-04-29  ZCST
# Z00000000000000240  Available to Order (PP)   2014-04-29  ZCST
# Z00000000000000241  Available to Order (PP)   2014-04-29  ZCST
# Z00000000000000521  Available to Order (PP)   2014-10-30  ZCST
# Z00000000000000522  Available to Order (PP)   2014-10-30  ZCST
# Z00000000000000523  Available to Order (PP)   2014-10-30  ZCST
# Z00000000000000524  Available to Order (PP)   2014-10-30  ZCST
# RE-PTX-X8-64G-LT-B  Available to Order (PP)   2015-04-21  ZFRT
# RE-PTX-X8-64G-LT-R  Available to Order (PP)   2015-04-21  ZFRT
# RE-PTX-X8-64G-LT-S  Available to Order (PP)   2015-04-21  ZFRT
# S-FPC3-PTX-UPG-2-L  Available to Order (PP)   2015-06-10  YFRT
# S-FPC3-PTX-UPG-2-R  Available to Order (PP)   2015-06-10  YFRT
# SRX4200-W-EWF-5     Available to Order (PP)   2015-09-20  YFRT
# SRX5K-RE2-CF        Available to Order (PP)   2016-03-08  ZFRT
# SRX5K-RE2-SSD       Available to Order (PP)   2016-03-08  ZFRT
# SRX4100-W-EWF-5     Available to Order (PP)   2016-04-26  YFRT
# QFX10000-18Q-PA     Available to Order (PP)   2016-06-09  YFRT
# BT8A78UFM6          Available to Order (PP)   2016-08-24  ZFRT
# JNP-SPC3            Available to Order (PP)   2016-11-21  ZFRT
# REMX2K-X8-128G-S-B  Available to Order (PP)   2016-12-11  ZFRT
# REMX2K-X8-128G-S-R  Available to Order (PP)   2016-12-11  ZFRT
# REMX2K-X8-128G-S-S  Available to Order (PP)   2016-12-11  ZFRT
# RE-PTX-X8-128G-S-B  Available to Order (PP)   2016-12-11  ZFRT
# RE-PTX-X8-128G-S-R  Available to Order (PP)   2016-12-11  ZFRT
#
#                    Material - Product Family (Text)
# Z00000000000000239             MX Series 3D Univers
# Z00000000000000240             MX Series 3D Univers
# Z00000000000000241             MX Series 3D Univers
# Z00000000000000521             MX Series 3D Univers
# Z00000000000000522             MX Series 3D Univers
# Z00000000000000523             MX Series 3D Univers
# Z00000000000000524             MX Series 3D Univers
# RE-PTX-X8-64G-LT-B             PTX Series Packet Tr
# RE-PTX-X8-64G-LT-R             PTX Series Packet Tr
# RE-PTX-X8-64G-LT-S             PTX Series Packet Tr
# S-FPC3-PTX-UPG-2-L             PTX Series Packet Tr
# S-FPC3-PTX-UPG-2-R             PTX Series Packet Tr
# SRX4200-W-EWF-5                 Threat Mitigation &
# SRX5K-RE2-CF                    SRX Series Services
# SRX5K-RE2-SSD                   SRX Series Services
# SRX4100-W-EWF-5                 Threat Mitigation &
# QFX10000-18Q-PA                 QFX Series Switches
# BT8A78UFM6                                      BTI
# JNP-SPC3                        SRX Series Services
# REMX2K-X8-128G-S-B             MX Series 3D Univers
# REMX2K-X8-128G-S-R             MX Series 3D Univers
# REMX2K-X8-128G-S-S             MX Series 3D Univers
# RE-PTX-X8-128G-S-B             PTX Series Packet Tr
# RE-PTX-X8-128G-S-R             PTX Series Packet Tr
